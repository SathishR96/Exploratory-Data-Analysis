# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
os.chdir('/home/sdr/Pictures/The scholar/Data analysis/Assignment 1/')
df=pd.read_csv('Top500_Indian_Cities.csv')
df
# Out:
#               city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
df.columns
# Out:
# Index(['city', 'state_code', 'state_name', 'dist_code', 'population_total',
#        'population_male', 'population_female', 'literates_total',
#        'literates_male', 'literates_female', 'sex_ratio',
#        'effective_literacy_rate_total', 'effective_literacy_rate_male',
#        'effective_literacy_rate_female', 'total_graduates', 'male_graduates',
#        'female_graduates'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# city                              0
# state_code                        0
# state_name                        0
# dist_code                         0
# population_total                  0
# population_male                   0
# population_female                 0
# literates_total                   0
# literates_male                    0
# literates_female                  0
# sex_ratio                         0
# effective_literacy_rate_total     0
# effective_literacy_rate_male      0
# effective_literacy_rate_female    0
# total_graduates                   0
# male_graduates                    0
# female_graduates                  0
# dtype: int64

# %%
df.nunique(axis=0)
# Out:
# city                              492
# state_code                         29
# state_name                         29
# dist_code                          61
# population_total                  493
# population_male                   493
# population_female                 493
# literates_total                   492
# literates_male                    493
# literates_female                  490
# sex_ratio                         195
# effective_literacy_rate_total     435
# effective_literacy_rate_male      413
# effective_literacy_rate_female    444
# total_graduates                   489
# male_graduates                    485
# female_graduates                  486
# dtype: int64

# %%
df.dtypes
# Out:
# city                               object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %% [markdown]
# # Which states have highest population count?

# %%
c=df.groupby('state_name',as_index=False).sum()
c.nlargest(1,'population_total')
# Out:
#      state_name  state_code  dist_code  population_total  population_male  \
# 14  MAHARASHTRA        1161        897          37722136         19961736
#
#     population_female  literates_total  literates_male  literates_female  \
# 14           17760400         30514278        16794767          13719511
#
#     sex_ratio  effective_literacy_rate_total  effective_literacy_rate_male  \
# 14      39582                         3862.6                       4044.74
#
#     effective_literacy_rate_female  total_graduates  male_graduates  \
# 14                         3665.93          5266151         2908234
#
#     female_graduates
# 14           2357917

# %% [markdown]
# # Compare literacy across the states.

# %%
sns.set(rc={'figure.figsize':(21,21.27)})
vc=df.groupby('state_name',as_index=False).sum()
print('\n')
print('Top 5 total graduates count across states')
vc.nlargest(5,'total_graduates')
# Out:
# Top 5 total graduates count across states
#         state_name  state_code  dist_code  population_total  population_male  \
# 14     MAHARASHTRA        1161        897          37722136         19961736
# 26   UTTAR PRADESH         567       1864          25302925         13433369
# 1   ANDHRA PRADESH        1176        707          18171615          9192368
# 28     WEST BENGAL        1159        762          18063509          9357777
# 11       KARNATAKA         754        349          15799896          8112840
#
#     population_female  literates_total  literates_male  literates_female  \
# 14           17760400         30514278        16794767          13719511
# 26           11869556         17669408         9858998           7810410
# 1             8979247         13463769         7178688           6285081
# 28            8705732         14606480         7823632           6782848
# 11            7687056         12474974         6667390           5807584
#
# ...

# %%
print('\n')
print('Top 5 Male graduates count across states')
vc.nlargest(5,'male_graduates')
# Out:
# Top 5 Male graduates count across states
#         state_name  state_code  dist_code  population_total  population_male  \
# 14     MAHARASHTRA        1161        897          37722136         19961736
# 26   UTTAR PRADESH         567       1864          25302925         13433369
# 1   ANDHRA PRADESH        1176        707          18171615          9192368
# 28     WEST BENGAL        1159        762          18063509          9357777
# 11       KARNATAKA         754        349          15799896          8112840
#
#     population_female  literates_total  literates_male  literates_female  \
# 14           17760400         30514278        16794767          13719511
# 26           11869556         17669408         9858998           7810410
# 1             8979247         13463769         7178688           6285081
# 28            8705732         14606480         7823632           6782848
# 11            7687056         12474974         6667390           5807584
#
# ...

# %%
print('\n')
print('Top 5 Female graduates count across states')
vc.nlargest(5,'female_graduates')
# Out:
# Top 5 Female graduates count across states
#         state_name  state_code  dist_code  population_total  population_male  \
# 14     MAHARASHTRA        1161        897          37722136         19961736
# 26   UTTAR PRADESH         567       1864          25302925         13433369
# 28     WEST BENGAL        1159        762          18063509          9357777
# 19    NCT OF DELHI         105        250          13481997          7201322
# 1   ANDHRA PRADESH        1176        707          18171615          9192368
#
#     population_female  literates_total  literates_male  literates_female  \
# 14           17760400         30514278        16794767          13719511
# 26           11869556         17669408         9858998           7810410
# 28            8705732         14606480         7823632           6782848
# 19            6280675         10379026         5816335           4562691
# 1             8979247         13463769         7178688           6285081
#
# ...

# %%
print('\n')
print('Top 5 Literates count across states')
vc.nlargest(5,'literates_total')
# Out:
# Top 5 Literates count across states
#         state_name  state_code  dist_code  population_total  population_male  \
# 14     MAHARASHTRA        1161        897          37722136         19961736
# 26   UTTAR PRADESH         567       1864          25302925         13433369
# 28     WEST BENGAL        1159        762          18063509          9357777
# 6          GUJARAT         696        322          17835049          9541688
# 1   ANDHRA PRADESH        1176        707          18171615          9192368
#
#     population_female  literates_total  literates_male  literates_female  \
# 14           17760400         30514278        16794767          13719511
# 26           11869556         17669408         9858998           7810410
# 28            8705732         14606480         7823632           6782848
# 6             8293361         14154728         7921271           6233457
# 1             8979247         13463769         7178688           6285081
#
# ...

# %%
print('\n')
print('Top 5 Male Literates count across states')
vc.nlargest(5,'literates_male')
# Out:
# Top 5 Male Literates count across states
#         state_name  state_code  dist_code  population_total  population_male  \
# 14     MAHARASHTRA        1161        897          37722136         19961736
# 26   UTTAR PRADESH         567       1864          25302925         13433369
# 6          GUJARAT         696        322          17835049          9541688
# 28     WEST BENGAL        1159        762          18063509          9357777
# 1   ANDHRA PRADESH        1176        707          18171615          9192368
#
#     population_female  literates_total  literates_male  literates_female  \
# 14           17760400         30514278        16794767          13719511
# 26           11869556         17669408         9858998           7810410
# 6             8293361         14154728         7921271           6233457
# 28            8705732         14606480         7823632           6782848
# 1             8979247         13463769         7178688           6285081
#
# ...

# %%
print('\n')
print('Top 5 Female Literates count across states')
vc.nlargest(5,'literates_female')
# Out:
# Top 5 Female Literates count across states
#         state_name  state_code  dist_code  population_total  population_male  \
# 14     MAHARASHTRA        1161        897          37722136         19961736
# 26   UTTAR PRADESH         567       1864          25302925         13433369
# 28     WEST BENGAL        1159        762          18063509          9357777
# 1   ANDHRA PRADESH        1176        707          18171615          9192368
# 6          GUJARAT         696        322          17835049          9541688
#
#     population_female  literates_total  literates_male  literates_female  \
# 14           17760400         30514278        16794767          13719511
# 26           11869556         17669408         9858998           7810410
# 28            8705732         14606480         7823632           6782848
# 1             8979247         13463769         7178688           6285081
# 6             8293361         14154728         7921271           6233457
#
# ...

# %% [markdown]
# # Top 10 cities with high literacy

# %%
y=df.groupby('state_name',as_index=False).sum()
y1=y.nlargest(10,['literates_total'])
sns.set(rc={'figure.figsize':(20,21)})
sns.set(font_scale=1.5)

# %%
sns.barplot(x='state_name',y='literates_total',data=y1)
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='literates_total'>

# %% [markdown]
# # Explore sex ratio of different states.

# %%
m=df.groupby('state_name',as_index=False).mean()
print('\n')
print('Top 5  with maximum sex ratio ')
m=m.nlargest(5,'sex_ratio')
pd.DataFrame(m)
# Out:
# Top 5  with maximum sex ratio
#     state_name  state_code  dist_code  population_total  population_male  \
# 12      KERALA        32.0        9.0     393710.428571    190802.142857
# 15    MANIPUR         14.0       99.0     264986.000000    128931.000000
# 16   MEGHALAYA        17.0        6.0     143007.000000     70028.000000
# 21  PUDUCHERRY        34.0        2.0     270900.500000    133179.500000
# 17     MIZORAM        15.0        3.0     291822.000000    143803.000000
#
#     population_female  literates_total  literates_male  literates_female  \
# 12      202908.285714    343079.571429   167606.857143     175472.714286
# 15      136055.000000    219261.000000   110809.000000     108452.000000
# 16       72979.000000    119313.000000    59420.000000      59893.000000
# 21      137721.000000    220062.500000   113541.000000     106521.500000
# 17      148019.000000    253588.000000   125256.000000     128332.000000
#
# ...

# %%
sns.barplot(x='state_name',y='sex_ratio',data=m)
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='sex_ratio'>

# %%
print('\n')
print('Bottom 5  States of sex ratio ')
n=df.groupby('state_name',as_index=False).mean()
n=n.nsmallest(5,'sex_ratio')
n
# Out:
# Bottom 5  States of sex ratio
#           state_name  state_code  dist_code  population_total  \
# 8   HIMACHAL PRADESH         2.0  11.000000         169758.00
# 4         CHANDIGARH         4.0   1.000000         960787.00
# 19      NCT OF DELHI         7.0  16.666667         898799.80
# 7            HARYANA         6.0   9.550000         297611.15
# 22            PUNJAB         3.0   9.812500         363867.25
#
#     population_male  population_female  literates_total  literates_male  \
# 8      93364.000000       76394.000000    147799.000000    82486.000000
# 4     525226.000000      435561.000000    743254.000000   426071.000000
# 19    480088.133333      418711.666667    691935.066667   387755.666667
# 7     159098.400000      138512.750000    224233.800000   126239.350000
# 22    194154.562500      169712.687500    276942.375000   153075.062500
#
#     literates_female   sex_ratio  effective_literacy_rate_total  \
# ...

# %%
sns.barplot(x='state_name',y='sex_ratio',data=n)
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='sex_ratio'>

# %% [markdown]
# # Percentage of total Graduate against Total Population of States.

# %%
f=df.groupby('state_name',as_index=False).sum()
f['percentage']=(f['total_graduates']/f['population_total'])*100
f=f[['state_name','percentage']]
f
# Out:
#                    state_name  percentage
# 0   ANDAMAN & NICOBAR ISLANDS   12.344943
# 1              ANDHRA PRADESH   15.140927
# 2                       ASSAM   17.430852
# 3                       BIHAR   13.256443
# 4                  CHANDIGARH   19.703847
# 5                CHHATTISGARH   14.348527
# 6                     GUJARAT   11.182178
# 7                     HARYANA   17.796275
# 8            HIMACHAL PRADESH   25.538119
# 9             JAMMU & KASHMIR   14.959277
# 10                  JHARKHAND   14.303108
# 11                  KARNATAKA   15.796433
# 12                     KERALA   16.705570
# 13             MADHYA PRADESH   14.449967
# 14                MAHARASHTRA   13.960373
# 15                   MANIPUR    24.120142
# 16                  MEGHALAYA   17.560679
# 17                    MIZORAM    9.194646
# 18                   NAGALAND   10.423584
# 19               NCT OF DELHI   18.129955
# 20                     ORISSA   17.652471
# ...

# %%
sns.set(font_scale=1)
sns.barplot(x='state_name',y='percentage',data=f)
# Out:
# <AxesSubplot:xlabel='state_name', ylabel='percentage'>

# %% [markdown]
# # States with most cities in Top 500.

# %%
e=df[['city','state_name']]
e['state_name'].value_counts()
# Out:
# UTTAR PRADESH                63
# WEST BENGAL                  61
# MAHARASHTRA                  43
# ANDHRA PRADESH               42
# MADHYA PRADESH               32
# TAMIL NADU                   32
# RAJASTHAN                    29
# GUJARAT                      29
# BIHAR                        26
# KARNATAKA                    26
# HARYANA                      20
# PUNJAB                       16
# NCT OF DELHI                 15
# JHARKHAND                    10
# ORISSA                       10
# CHHATTISGARH                  9
# KERALA                        7
# UTTARAKHAND                   6
# ASSAM                         4
# JAMMU & KASHMIR               3
# PUDUCHERRY                    2
# CHANDIGARH                    1
# HIMACHAL PRADESH              1
# NAGALAND                      1
# TRIPURA                       1
# ANDAMAN & NICOBAR ISLANDS     1
# MEGHALAYA                     1
# MANIPUR                       1
# MIZORAM                       1
# ...

# %% [markdown]
# # Find some more meaningful insights from the data.

# %%
sa=df.groupby('state_name',as_index=False).mean()
sa=sa.drop(['state_code','dist_code'],axis=1)
print('\n')
print('Top 5 states with maximum Total Efective Literacy Rate')
sa.nlargest(5,'effective_literacy_rate_total')
# Out:
# Top 5 states with maximum Total Efective Literacy Rate
#           state_name  population_total  population_male  population_female  \
# 17           MIZORAM     291822.000000    143803.000000      148019.000000
# 12            KERALA     393710.428571    190802.142857      202908.285714
# 8   HIMACHAL PRADESH     169758.000000     93364.000000       76394.000000
# 25           TRIPURA     399688.000000    199616.000000      200072.000000
# 16         MEGHALAYA     143007.000000     70028.000000       72979.000000
#
#     literates_total  literates_male  literates_female    sex_ratio  \
# 17    253588.000000   125256.000000     128332.000000  1029.000000
# 12    343079.571429   167606.857143     175472.714286  1066.714286
# 8     147799.000000    82486.000000      65313.000000   818.000000
# 25    343633.000000   174524.000000     169109.000000  1002.000000
# 16    119313.000000    59420.000000      59893.000000  1042.000000
#
# ...

# %%
print('\n')
print('Top 5 states with maximum MALE Efective Literacy Rate')
sa.nlargest(5,'effective_literacy_rate_male')
# Out:
# Top 5 states with maximum MALE Efective Literacy Rate
#           state_name  population_total  population_male  population_female  \
# 17           MIZORAM     291822.000000    143803.000000      148019.000000
# 12            KERALA     393710.428571    190802.142857      202908.285714
# 15          MANIPUR      264986.000000    128931.000000      136055.000000
# 8   HIMACHAL PRADESH     169758.000000     93364.000000       76394.000000
# 25           TRIPURA     399688.000000    199616.000000      200072.000000
#
#     literates_total  literates_male  literates_female    sex_ratio  \
# 17    253588.000000   125256.000000     128332.000000  1029.000000
# 12    343079.571429   167606.857143     175472.714286  1066.714286
# 15    219261.000000   110809.000000     108452.000000  1055.000000
# 8     147799.000000    82486.000000      65313.000000   818.000000
# 25    343633.000000   174524.000000     169109.000000  1002.000000
#
# ...

# %%
print('\n')
print('Top 5 states with maximum FEMALE Efective Literacy Rate')
sa.nlargest(5,'effective_literacy_rate_female')
# Out:
# Top 5 states with maximum FEMALE Efective Literacy Rate
#           state_name  population_total  population_male  population_female  \
# 17           MIZORAM     291822.000000    143803.000000      148019.000000
# 12            KERALA     393710.428571    190802.142857      202908.285714
# 8   HIMACHAL PRADESH     169758.000000     93364.000000       76394.000000
# 25           TRIPURA     399688.000000    199616.000000      200072.000000
# 16         MEGHALAYA     143007.000000     70028.000000       72979.000000
#
#     literates_total  literates_male  literates_female    sex_ratio  \
# 17    253588.000000   125256.000000     128332.000000  1029.000000
# 12    343079.571429   167606.857143     175472.714286  1066.714286
# 8     147799.000000    82486.000000      65313.000000   818.000000
# 25    343633.000000   174524.000000     169109.000000  1002.000000
# 16    119313.000000    59420.000000      59893.000000  1042.000000
#
# ...

# %%
print('\n')
print('Top 5 states with average  population')
sa.nlargest(5,'population_total')
# Out:
# Top 5 states with average  population
#       state_name  population_total  population_male  population_female  \
# 4     CHANDIGARH     960787.000000    525226.000000      435561.000000
# 19  NCT OF DELHI     898799.800000    480088.133333      418711.666667
# 14   MAHARASHTRA     877258.976744    464226.418605      413032.558140
# 6        GUJARAT     615001.689655    329023.724138      285977.965517
# 11     KARNATAKA     607688.307692    312032.307692      295656.000000
#
#     literates_total  literates_male  literates_female   sex_ratio  \
# 4     743254.000000   426071.000000     317183.000000  829.000000
# 19    691935.066667   387755.666667     304179.400000  861.533333
# 14    709634.372093   390575.976744     319058.395349  920.511628
# 6     488094.068966   273147.275862     214946.793103  913.172414
# 11    479806.692308   256438.076923     223368.615385  987.115385
#
#     effective_literacy_rate_total  effective_literacy_rate_male  \
# ...

# %%
print('\n')
print('Top 5 states with average  Male population')
sa.nlargest(5,'population_male')
# Out:
# Top 5 states with average  Male population
#          state_name  population_total  population_male  population_female  \
# 4        CHANDIGARH     960787.000000    525226.000000      435561.000000
# 19     NCT OF DELHI     898799.800000    480088.133333      418711.666667
# 14      MAHARASHTRA     877258.976744    464226.418605      413032.558140
# 6           GUJARAT     615001.689655    329023.724138      285977.965517
# 9   JAMMU & KASHMIR     601662.333333    317764.000000      283898.333333
#
#     literates_total  literates_male  literates_female   sex_ratio  \
# 4     743254.000000   426071.000000     317183.000000  829.000000
# 19    691935.066667   387755.666667     304179.400000  861.533333
# 14    709634.372093   390575.976744     319058.395349  920.511628
# 6     488094.068966   273147.275862     214946.793103  913.172414
# 9     408738.333333   231305.333333     177433.000000  907.666667
#
#     effective_literacy_rate_total  effective_literacy_rate_male  \
# ...

# %%
print('\n')
print('Top 5 states with average  Female population')
sa.nlargest(5,'population_female')
# Out:
# Top 5 states with average  Female population
#       state_name  population_total  population_male  population_female  \
# 4     CHANDIGARH     960787.000000    525226.000000      435561.000000
# 19  NCT OF DELHI     898799.800000    480088.133333      418711.666667
# 14   MAHARASHTRA     877258.976744    464226.418605      413032.558140
# 11     KARNATAKA     607688.307692    312032.307692      295656.000000
# 6        GUJARAT     615001.689655    329023.724138      285977.965517
#
#     literates_total  literates_male  literates_female   sex_ratio  \
# 4     743254.000000   426071.000000     317183.000000  829.000000
# 19    691935.066667   387755.666667     304179.400000  861.533333
# 14    709634.372093   390575.976744     319058.395349  920.511628
# 11    479806.692308   256438.076923     223368.615385  987.115385
# 6     488094.068966   273147.275862     214946.793103  913.172414
#
#     effective_literacy_rate_total  effective_literacy_rate_male  \
# ...

# %%
print('\n')
print('Top 5 states with average  Literates')
sa.nlargest(5,'literates_total')
# Out:
# Top 5 states with average  Literates
#       state_name  population_total  population_male  population_female  \
# 4     CHANDIGARH     960787.000000    525226.000000      435561.000000
# 14   MAHARASHTRA     877258.976744    464226.418605      413032.558140
# 19  NCT OF DELHI     898799.800000    480088.133333      418711.666667
# 6        GUJARAT     615001.689655    329023.724138      285977.965517
# 11     KARNATAKA     607688.307692    312032.307692      295656.000000
#
#     literates_total  literates_male  literates_female   sex_ratio  \
# 4     743254.000000   426071.000000     317183.000000  829.000000
# 14    709634.372093   390575.976744     319058.395349  920.511628
# 19    691935.066667   387755.666667     304179.400000  861.533333
# 6     488094.068966   273147.275862     214946.793103  913.172414
# 11    479806.692308   256438.076923     223368.615385  987.115385
#
#     effective_literacy_rate_total  effective_literacy_rate_male  \
# ...

# %%
print('\n')
print('Top 5 states with average  Male Literates')
sa.nlargest(5,'literates_male')
# Out:
# Top 5 states with average  Male Literates
#       state_name  population_total  population_male  population_female  \
# 4     CHANDIGARH     960787.000000    525226.000000      435561.000000
# 14   MAHARASHTRA     877258.976744    464226.418605      413032.558140
# 19  NCT OF DELHI     898799.800000    480088.133333      418711.666667
# 6        GUJARAT     615001.689655    329023.724138      285977.965517
# 11     KARNATAKA     607688.307692    312032.307692      295656.000000
#
#     literates_total  literates_male  literates_female   sex_ratio  \
# 4     743254.000000   426071.000000     317183.000000  829.000000
# 14    709634.372093   390575.976744     319058.395349  920.511628
# 19    691935.066667   387755.666667     304179.400000  861.533333
# 6     488094.068966   273147.275862     214946.793103  913.172414
# 11    479806.692308   256438.076923     223368.615385  987.115385
#
#     effective_literacy_rate_total  effective_literacy_rate_male  \
# ...

# %%
print('\n')
print('Top 5 states with average  Female Literates')
sa.nlargest(5,'literates_female')
# Out:
# Top 5 states with average  Female Literates
#       state_name  population_total  population_male  population_female  \
# 14   MAHARASHTRA     877258.976744    464226.418605      413032.558140
# 4     CHANDIGARH     960787.000000    525226.000000      435561.000000
# 19  NCT OF DELHI     898799.800000    480088.133333      418711.666667
# 11     KARNATAKA     607688.307692    312032.307692      295656.000000
# 6        GUJARAT     615001.689655    329023.724138      285977.965517
#
#     literates_total  literates_male  literates_female   sex_ratio  \
# 14    709634.372093   390575.976744     319058.395349  920.511628
# 4     743254.000000   426071.000000     317183.000000  829.000000
# 19    691935.066667   387755.666667     304179.400000  861.533333
# 11    479806.692308   256438.076923     223368.615385  987.115385
# 6     488094.068966   273147.275862     214946.793103  913.172414
#
#     effective_literacy_rate_total  effective_literacy_rate_male  \
# ...

# %%
print('\n')
print('Top 5 states with average  Graduates')
sa.nlargest(5,'total_graduates')
# Out:
# Top 5 states with average  Graduates
#          state_name  population_total  population_male  population_female  \
# 4        CHANDIGARH     960787.000000    525226.000000      435561.000000
# 19     NCT OF DELHI     898799.800000    480088.133333      418711.666667
# 14      MAHARASHTRA     877258.976744    464226.418605      413032.558140
# 11        KARNATAKA     607688.307692    312032.307692      295656.000000
# 9   JAMMU & KASHMIR     601662.333333    317764.000000      283898.333333
#
#     literates_total  literates_male  literates_female   sex_ratio  \
# 4     743254.000000   426071.000000     317183.000000  829.000000
# 19    691935.066667   387755.666667     304179.400000  861.533333
# 14    709634.372093   390575.976744     319058.395349  920.511628
# 11    479806.692308   256438.076923     223368.615385  987.115385
# 9     408738.333333   231305.333333     177433.000000  907.666667
#
#     effective_literacy_rate_total  effective_literacy_rate_male  \
# ...

# %%
print('\n')
print('Top 5 states with average  Male Graduates')
sa.nlargest(5,'male_graduates')
# Out:
# Top 5 states with average  Male Graduates
#          state_name  population_total  population_male  population_female  \
# 4        CHANDIGARH     960787.000000    525226.000000      435561.000000
# 19     NCT OF DELHI     898799.800000    480088.133333      418711.666667
# 14      MAHARASHTRA     877258.976744    464226.418605      413032.558140
# 11        KARNATAKA     607688.307692    312032.307692      295656.000000
# 9   JAMMU & KASHMIR     601662.333333    317764.000000      283898.333333
#
#     literates_total  literates_male  literates_female   sex_ratio  \
# 4     743254.000000   426071.000000     317183.000000  829.000000
# 19    691935.066667   387755.666667     304179.400000  861.533333
# 14    709634.372093   390575.976744     319058.395349  920.511628
# 11    479806.692308   256438.076923     223368.615385  987.115385
# 9     408738.333333   231305.333333     177433.000000  907.666667
#
#     effective_literacy_rate_total  effective_literacy_rate_male  \
# ...

# %%
print('\n')
print('Top 5 states with average  Female Graduates')
sa.nlargest(5,'female_graduates')
# Out:
# Top 5 states with average  Female Graduates
#          state_name  population_total  population_male  population_female  \
# 4        CHANDIGARH     960787.000000    525226.000000      435561.000000
# 19     NCT OF DELHI     898799.800000    480088.133333      418711.666667
# 14      MAHARASHTRA     877258.976744    464226.418605      413032.558140
# 11        KARNATAKA     607688.307692    312032.307692      295656.000000
# 9   JAMMU & KASHMIR     601662.333333    317764.000000      283898.333333
#
#     literates_total  literates_male  literates_female   sex_ratio  \
# 4     743254.000000   426071.000000     317183.000000  829.000000
# 19    691935.066667   387755.666667     304179.400000  861.533333
# 14    709634.372093   390575.976744     319058.395349  920.511628
# 11    479806.692308   256438.076923     223368.615385  987.115385
# 9     408738.333333   231305.333333     177433.000000  907.666667
#
#     effective_literacy_rate_total  effective_literacy_rate_male  \
# ...
